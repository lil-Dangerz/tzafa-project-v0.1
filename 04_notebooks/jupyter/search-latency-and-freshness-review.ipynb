# %% [markdown]
# # Dummy Search Latency and Freshness Review
#
# This notebook exists only to validate notebook routing and registry behavior on the dry-run branch.

# %%
import pandas as pd

latency = pd.read_json('../..//02_evidence/search-api-latency-sample-2026-06-29.ndjson', lines=True)
freshness = pd.read_csv('../..//02_evidence/catalog-index-freshness-export-2026-06-29.csv')

latency.head(), freshness.head()
